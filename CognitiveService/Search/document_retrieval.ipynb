# %%
import openai
from openai import AzureOpenAI
from tenacity import retry, wait_random_exponential, stop_after_attempt  

from azure.core.credentials import AzureKeyCredential 
from azure.search.documents import SearchClient  

from azure.search.documents.models import VectorizedQuery
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# %%
import json
import os
from dotenv import load_dotenv

# %%
load_dotenv("pfd_conf.env")
container_name = "cvjson"  # Name of the container in Blob Storage
blob_name = 'salida.json'  # Name of the JSON file in Blob Storage
blob_vectorname = 'docVectors.json'

connect_str = os.getenv("AZURE_STORAGE_CONNECTION_STRING")
service_endpoint = os.getenv("AZURE_STORAGE_SERVICE_ENDPOINT")

index_name = os.getenv("AZURE_SEARCH_INDEX_NAME")
key = os.getenv("AZURE_SEARCH_KEY")

model = os.getenv("AZURE_EMBEDDINGS_MODEL")
credential = AzureKeyCredential(key)


client_embeddings = AzureOpenAI(
  api_key = os.getenv("OPENAI_EMBEDDINGS_KEY"),  
  api_version = os.getenv("OPENAI_EMBEDDINGS_VERSION"),
  azure_endpoint = os.getenv("OPENAI_EMBEDDINGS_ENDPOINT")
)

endpoint = os.getenv("AZUREOPENAI_ENDPOINT")
deployment = os.getenv("AZUREOPENAI_DEPLOYMENT")

 
client = AzureOpenAI(
    azure_endpoint=endpoint,
    api_key="51ce1634b07b4fd0b774b30e2d6d8f8b",
    api_version="2024-02-01",
)

# %% [markdown]
# # Function to chat with your documents
#
# To chat with your documents you'll need to upload the vectorized documents on azure search
#
# this way it will look for the best machof your query
#
# the the results will the feeded into a gpt model

# %%
import unicodedata

def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return ''.join([c for c in nfkd_form if not unicodedata.combining(c)])

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def generate_embeddings(text, model=model):
    return client_embeddings.embeddings.create(input = [text], model=model).data[0].embedding

# %%
def seleccionaTop(text):
    n_ret = 5
    arr_numstring = ["uno", "dos", "tres", "cuatro", "cinco", "seis", "siete", "ocho", "nueve", "diez", "once", "doce", "trece", "catorce", "quince"]
    for i, num_string in enumerate(reversed(arr_numstring), start=1):
        
        if num_string in text or str( (len(arr_numstring) + 1 )- i) in text:
            if int((len(arr_numstring) + 1 ) - i) > 10:
                return False, int((len(arr_numstring) + 1 ) - i)
            if int((len(arr_numstring) + 1 ) - i) < 5:
                return True, 6
            
            return  True, int(((len(arr_numstring) + 1 ) - i) * 1.5)
    
    return True, 6

# %%
def azure_cognitive_search(query, top):
    search_client = SearchClient(service_endpoint, index_name, credential=credential)
    embedding = generate_embeddings(query)
    vector_query_content = VectorizedQuery(vector=embedding, 
                                    k_nearest_neighbors=23, 
                                    fields= "contentVector",
                                    exhaustive=True)
    
    results = search_client.search(  
        search_text=query,  
        vector_queries=[vector_query_content],
        select=["Area", "content", "filename"],
        top= top
    )

    mess = ""
    filename = []
    folder = []
    cont_result = 0

    for result in results:
        mess += (
            #f"Area donde trabaja: {result['Area']}\n"
            f"Contenido del CV: {result['content']}\n **** "
        )
        folder.append(f"/Documentos compartidos/General/{result['Area']}")
        filename.append(result['filename'])
    
    return mess, folder, filename

# %%
def azure_openai(query, prompt_results = "", isIntro = False):
    if not isIntro:
        
        prompt =[
            {
                "role": "system",
                "content": "Eres un chatbot de inteligencia artificial de la empresa Global Hitss (GH), diseñado para ofrecer información sobre los currículos de los empleados. Cada currículum detalla las diversas habilidades y conocimientos de los empleados. Asegúrate de que la respuesta vaya acorde a la consulta que te están haciendo. Los archivos de curriculum a los que tienes acceso están delimitados por '****', separados por personas. Cada documento contiene los siguientes campos: Nombre completo, Resumen profesional, Resumen de habilidades técnicas, Experiencia laboral, habilidades técnicas, Cursos y certificaciones, educación e Idiomas (o Inglés), estos campos están en orden."
            },
            {
                "role": "system",
                "content": "Para mejorar la comprensión, cada respuesta se presenta en formato estructurado. Siempre Los nombres de las personas se destacan en negritas (Nombre Segundo Nombre y Apellido paterno), esto es lo único que se resalta en negritas. Se inicia siempre con el nombre del colaborador, seguido de una lista con viñetas de sus características relevantes con respecto a la pregunta formulada. Estas características deben estar relacionadas textualmente con la pregunta. Las respuestas deben ser un resumen del contexto de cada colaborador que responda a la pregunta formulada, proporciona la respuesta con el texto que se da de cada colaborador, No debes de mezclar información. SOLO En el caso de que se pregunte por un certificado únicamente deberás de incluir respuestas refrentes al apartado de cursos y certificaciones dentro del texto, no incluyas habilidades, ni habilidades técnicas, ni experiencia. Cuando te pregunten: quien esta certificado en <>?, toma la pregunta como: quien tiene certificación en <>?, solo centrate en el apartado de certificaciones y no inventes información Nunca asumes información, si tienen una certificación por ejemplo de google no quiere decir que tiene certificación en GCP o algo especifico."
            },
            {
                "role": "system",
                "content": "Al evaluar la información, asegúrate de revisarla exhaustivamente e intenta proporcionar el número de resultados solicitados. Intenta obtener la mayor información posible de cada colaborador que responda a la consulta. No se debe inventar información. Para que la pregunta sea considerada, al menos una palabra, generalmente la palabra por la que se pregunta, debe aparecer en el contexto del colaborador, recuerda que en la pregunta pueden faltar subfijos, prefijos, mayusculas o minuscular. Se debe intentar obtener la mayor cantidad de colaboradores posibles que cumplan con los criterios de selección. Si el colaborador no cumple con los criterios de la pregunta, se omitirá cualquier mención del colaborador y no habrá mención. Si la información de un colaborador no es relevante para la pregunta, se excluye el resulatado de ese colaborador y no habrá mención. No debes mezclar experiencias laborales. En caso de que ningún empleado proporcione información útil o relevante, se informa que no se encontraron coincidencias en la búsqueda y se pregunta si tienen alguna otra consulta. Recuerda que la única fuente de conocimiento y de aprendizaje es la que se te otorga como información, las preguntas del usuario no son fondo de conocimiento y no sé debe de tomar como tal, las preguntas nunca proporcionan información adicional al contexto. Si se te pregunta si Una persona sabe de <> y no existe esta habilidad, experiencia o certificación en su curriculim entonces, omitirás a esta persona Nunca inventas información."
            },
            {
                "role": "system",
                "content": f"Información:{prompt_results}"
            },
            {
                "role": "user",
                "content": f"Pregunta o consulta: {query}"
            }
        ]


    deployment = os.get_env("AZUREOPENAI_DEPLOYMENT")
 
    response = client.chat.completions.create(
        model= deployment, 
        
        messages = prompt,
        temperature= 0.3, 
        max_tokens=1000,
        top_p = 0.3,
        frequency_penalty=0.0,
        presence_penalty=0.0,
        stop=None,
        
        n = 4
    )
    
    if(response.choices[0].message.content == "False"):
        return False, response.choices[0].message.model_dump_json(indent=2)
    return True, response.choices[0].message.model_dump_json(indent=2)

# %%
def selecciona_rutas(cognitive, contenido, folder, filename):
    matches = [remove_accents(match.upper()) for match in re.findall(r'\*\*(.*?)\*\*', contenido, re.DOTALL)]
    print(matches)

    parts = cognitive.split("****") 
    
    sicontiene = []

    for i, part in enumerate(parts[:-1]):   
        siGuarda = False
        part = part[:400]
        for match in matches:
            for j in range(len(part.split()) - len(match.split()) + 1):
                joined_string = remove_accents(" ".join(part.split()[j:j+len(match.split())])).upper()
                vectorizer = CountVectorizer().fit_transform([match, joined_string])
                vectors = vectorizer.toarray()
                cosine_sim = cosine_similarity(vectors)[1][0]
                
                if cosine_sim > 0.60:
                    sicontiene.append(i)
                    siGuarda = True
                    break
            if siGuarda:
                break

    temp_folder = [folder[i] for i in sicontiene]
    temp_filename = [filename[i] for i in sicontiene]
    return temp_folder, temp_filename

# %%
def responde(query):
    Menos10, top = seleccionaTop(query)
    cognitive, folder, filename = azure_cognitive_search(query, top) 

    if Menos10:
        try:
            _, respuesta = azure_openai(query, prompt_results=cognitive, isIntro=False)
            json_data = json.loads(respuesta)
            contenido = json_data["content"]
            folder, filename = selecciona_rutas(cognitive, contenido, folder, filename)
            return folder, filename, respuesta
        except Exception as e:
                error_message = "Lo sentimos, ha ocurrido un error en la ejecución.\nEstos son los resultados crudos de tu búsqueda"
                respuesta =json.dumps({"content": error_message})
                return folder, filename, respuesta
    else:
        error_message = "Por ahora puedo arrojar más de 10 resultados, intenta modificando tu solicitud.\nAquí tienes los archivos crudos de tu búsqueda"
        respuesta =json.dumps({"content": error_message})    
    
    return folder, filename, respuesta

# %% [markdown]
# # Tests

# %% [markdown]
# Integrate test

# %%
query = "Dame 4 perfiles con experiencia en DevOps y que sean de Global Hitss Cono Sur"
folder, filename, resp = responde(query)
json_data = json.loads(resp)

contenido = json_data["content"]
print(contenido)
separado = contenido.split("\n")
# Out:
# ['ALAN JAVIER CANELLAS', 'PUESTO ACTUAL:', 'EXPERIENCIA EN DEVOPS:', 'SOLIDO CONNECTING SOLUTIONS:', 'SOPORTE IT:', 'DIEGO JOSE GUILLEN BARRETO', 'PUESTO ACTUAL:', 'EXPERIENCIA EN DEVOPS:', 'GLOBAL HITSS CONO SUR:', 'LITEBOX ONLINE STRATEGIES:', 'FACUNDO VALENTIN CUPELLO', 'PUESTO ACTUAL:', 'EXPERIENCIA EN DEVOPS:', 'GLOBAL HITSS CONO SUR:', 'SCRUM MASTER:', 'MATIAS GERMAN PONCE', 'PUESTO ACTUAL:', 'EXPERIENCIA EN DEVOPS:', 'GLOBAL HITSS CONO SUR:', 'GLOBANT:']
# Aquí tienes 4 perfiles de empleados de Global Hitss Cono Sur con experiencia en DevOps:
#
# **Alan Javier Cañellas**
# - **Puesto Actual:** Backend Developer
# - **Experiencia en DevOps:**
#   - **Solido Connecting Solutions:** Maquetación, estilizado y programación de aplicaciones web, trabajando en conjunto con el área de back-end. Mantenimiento y optimización de las mismas.
#   - **Soporte IT:** Soporte técnico remoto y presencial de infraestructura de software para empresas varias, utilizando sistemas de gestión de tickets.
#
# **Diego Jose Guillen Barreto**
# - **Puesto Actual:** IT Project Manager & Release Train Engineer
# - **Experiencia en DevOps:**
#   - **Global Hitss Cono Sur:** Mejora del flujo de valor a través de value streams, mejorando y evaluando la competencia de DevOps y Release on Demand.
#   - **Litebox Online Strategies:** Responsable de la gestión y presentación de estimaciones, análisis de costos, consideraciones de diseño e implementación de cronogramas.
#
# **Facundo Valentin Cupello**
# - **Puesto Actual:** Presale of Cloud Services
# - **Experiencia en DevOps:**
#   - **Global Hitss Cono Sur:** Preventa de servicios hacia nubes públicas AWS, VCLOUD, AZURE, MULTICLOUD. Confección de estimaciones presupuestarias, propuestas técnicas y económicas.
#   - **Scrum Master:** Gestión de proyectos bajo metodologías ágiles.
#
# **Matias German Ponce**
# - **Puesto Actual:** AWS Cloud Support
# - **Experiencia en DevOps:**
#   - **Global Hitss Cono Sur:** Soporte en la nube de AWS para Clarovideo, utilizando tecnologías como Kubernetes, Terraform, Jenkins y Ansible. Trabajo con varias nubes, incluyendo AWS, Azure y QRO.
#   - **Globant:** Soporte y mantenimiento de GCP para cuenta extranjera con tecnología serverless y Kubernetes.
#
# ¿Hay algo más en lo que pueda ayudarte?

# %%
print(folder, filename)
# Out:
# ['/Documentos compartidos/General/ARGENTINA', '/Documentos compartidos/General/ARGENTINA', '/Documentos compartidos/General/ARGENTINA', '/Documentos compartidos/General/ARGENTINA', '/Documentos compartidos/General/ARGENTINA', '/Documentos compartidos/General/ARGENTINA'] ['TOMAS MARTINHO.pdf', 'ALAN JAVIER CAÑELLAS.pdf', 'DIEGO SERGIO ANGEL.pdf', 'DIEGO JOSE GUILLEN BARRETO.pdf', 'FACUNDO VALENTIN CUPELLO.pdf', 'MATIAS GERMAN PONCE.pdf']

# %% [markdown]
# # tests by part

# %% [markdown]
# ### Cognitive services document retrieval

# %%
query = "puedes darme perfiles con experiencia en SAP FI?"

# %%
Menos10, top = seleccionaTop(query)
print(Menos10, top)
# Out:
# True 5

# %%
cognitive, folder, filename = azure_cognitive_search(query, top)

# %%
filename
# Out:
# ['GUSTAVO ALBERTO DEYA.pdf',
#  'DIEGO DE LA CRUZ ARROYO.pdf',
#  'JULIAN MATIAS BERMOLEN.pdf',
#  'DIEGO JOSE GUILLEN BARRETO.pdf',
#  'DIEGO JOSE GUILLEN BARRETO.pdf']

# %%
parts = cognitive.split("****")
for part in parts:
    print(part)
# Out:
# Contenido del CV: AGUILAR PAZMIÑO DAVID ALEXIS Ing. Asdruval Conza Otuna
# 095 879 0458
# asdruval_94@hotmail.com
# Ing. Ingrid Giraldo de Univ. Guayaquil
# 0994885355
# ingrid.giraldom@ug.edu.ec
# Ing. Pazmiño Lucio Santiago de Claro
# 0996386783
# spazmin0@claro.com.ecSoy una persona proactiva, puntual, responsable, con valores éticos y morales, lleno de energía y
# vitalidad. Tengo experiencia en servicio al cliente, soporte y mantenimiento de dispositivos
# electrónicos en general. Me adapto rápido a cualquier tipo de ambiente laboral y trato de acoplarme
# fácilmente con el equipo de trabajo. Sé trabajar bajo presión, facilidad de palabra, rápido aprendizaje.
# COLEGIO FISCAL TECNICO PROVINCIA
# DE BOLIVAR, GUAYAQUIL
# BACHILLER CONTABLEEDUCACIÓN EXPERIENCIA LABORAL
# Call center
# Soporte técnico, recibir o realizar llamadas
# para responder dudas y resolver cualquier
# inconveniente.
# Atencion de cliente servicio masivo.Telenews. Febrero 2021-Abril 2021
# UNIVERSIDAD DE GUAYAQUIL
# INGENIERO EN NETWORKING Y
# TELECOMINUCACIONES
# REFERENCIAS PERSONALESPublinext S.A, Junio 2021 - Febrero 2022
# Atención de servicio cliente masivo
# Solucionar inconvenientes que se presenten
# en los programas de trabajo(Zoiper,POP3)
# Monitoreo de los estados de tx y rx de los
# routers.
# Registro y monitoreo en la base de datos
# MySQL.
# Mantenimiento preventivo y correctivo de
# laptop e impresoras y dispositivos móviles.
# Configuración e instalación de circuito
# cerrado (Hikvision, ACTI, AXIS CISCO).Soporte técnico david_131935@hotmail.com CI: 0955469606
# SOBRE MIGuayaquil-Guayacanes Mz210 V12Licencia de conducir
# profesional (Tipo c)Cel: 0969923450AÑO 2021
# Instalador de fibra óptica/CISCO.
# Año 2022
# Fundamentos de Networking para redes
# IP/CISCO.
# Conectividad IP y protocolo de
# ruteo/CISCO.
# Año 2023
# Instalador de fibra óptica/Capacítate para
# el empleo.
# Técnico en seguridad informática
# /Capacítate para el empleo.
# Técnico en sistemas informáticos/
# Diplomado/Capacítate para el empleo.
# HABILIDADES
# Liderazgo en equipo
# Proactivo
# Resiliencia
# Paquete Microsoft Office-Word, Excel,
# PowerPoint, Outlook(Avanzado)
# Access, OneNote, Outlook,
# Visio(Intermedio)
# Manejo de aplicaciones de seguridad
# (Hikvision, ACTI, AXIS CISCO)
# Conocimiento en routers marcas CISCO ,
# TP-Link y HUAWEI.
# Idioma-Inglés
# Nivel Oral y escrito Intermedio. CURSOSPolifuncional
# Cajero
# PolifuncionalMcDonald’s,  Nobiembre2019 - Abril 2020Caja- Asistente administrativo
# Cajero
# PolifuncionalBoloncity,  Julio2020 - Diciembre 2020
#
#  Contenido del CV: PAZMIÑO SALAS JOSE ANTONIO CURRICULUM VITAE Jot6 Antonio Paamllo Salat Dirección: Isla Trinitaria Mz. 6 Sir. 15 Teléfono: 0991833434 Email: jose15pazmino@gmail.com DATOS PERSONALES Fecha De Nacimiento: 15 de Agosto de 1991 27 Años Edad: Lugar De Nacimiento: Nacionalidad: Estado Civil: Cedula: ESTUDIOS REALIZADOS Superior Título Obtenido Secundaria Título Obtenido Especialización Primaria CURSOS REALIZADOS Guayaquil Ecuatoriano Soltero 093041951-0 Universidad De Guayaquil Facultad de Ciencias Matemáticas y Físicas Carrera de Ing. en Sistemas Computacionales Ingeniero en Sistemas Computacionales Colegio Fiscal "Ati II Pillahuaso" Técnico En Comercio Y Administración INFORMÁTICA Escuela Particular Mixta "Marco Espinoza" Curso De Mantenimiento de Computadoras SECAP Curso De Computación (Windows, Word Y Excel) Básico Universidad De Guayaquil Curso De Mantenimiento de Computadoras
# _______________ .. Universidad De Guayaquil Capacitación empresarial SQL 48 horas -CORLASOSA PL/SQL 48 horas -CORLASOSA JAVA 72horas -CORLASOSA JSP 96 horas -CORLASOSA Programas manejados Oracle PL/SQL SQL Java Java Script JSP SOAP HTML Conocimiento Herramientas Informáticas Ides • MyEclypse • Eclipse • Dreamweaver Servidores • TOMCAT Base de Datos • Oracle • PL-SQL Developer "Herramientas de Desarrollo" Sistemas Operativos • Linux: • PC Windows XP: • PC Windows 7: • PC Windows 8: Seniority Principiante Seniority Senior Seniority Senior Seniority Senior Corporación Latinoamericana de Software -01 Julio 2013 -10 Abril 2018 CORLASOSA -Sector: Carchi y 9 de Octubre Asesor en desarrollo de Software Desarrollar proyectos asignados (Leng: PI/Sql, JAVA, JSP, Oracle Ides: MyEclypse, Eclypse)
# GLOBALHITSS Asesor en desarrollo de Software Desarrollar proyectos asignados (Leng: PI/Sql, JAVA, JSP, Oracle Ides: Eclypse) 11 Abril 2018 hasta la actualidad Sector: Av. Francisco de Orellana Trabajo actualmente para una empresa de telecomunicaciones en proyecto de cambios continuos en recargas. Tareas anteriormente realizadas: • Modificaciones de las diferentes opciones del portal del Axis 2.3. • Modificación en el Portal Interno de recargas. • Ajustes en opciones del Portal de Retails. Diana Malina Salas Técnico Operador en Servicios Nacional del Ecuador Teléfono: 0998511925 Ing. Galo Gabriel Galarza Acosta Ingeniero en Desarrollo Teléfono: 0993501202 Ret:e_rencias_-i.abo,ral~s. Ing. Allyson Mora Mera CORLASOSA Líder de Proyectos Teléfono: 0986487263 Ing. Jimmy Eduardo Chango CORLASOSA Asesor de Software Teléfono: 0996397688 Ing. Arturo Zamora CORLASOSA Asesor de Software Teléfono: 0991865558
#
#
#  Contenido del CV: DAVID STALING VALVERDE VALDIGLESIAS                                               CURRICULU M VITAE
#
# Nombre: David Staling Valverde  Valdigles ias
# Celular:  937805214
# Correo:  stalingsv@gmail.com
# Dirección: Calle Baquijano y carrillo 121, Comas, Lima
# DNI:  47485810
#
# Experiencia  Laboral
# Jul 2022  – Oct 2023 Analista Networking Ciberseguridad  - STEFANINI
# Análisis  de casos de clientes  Empresariales con seguridad
# administrada y generación de ticket  cambios e incidencias  y
# resolución. Backoffice  configuración de equipamiento Fortigate  y
# Palo Alto (Políticas de navegación y denegación, enrutamiento
# estático, dinámico, intercomunicación de  redes, traffic shaping ,
# Nateo, VPN SSL, VPN I Psec, Bookmark,  etc.). Generación de reportes
# y análisis de trafico y ataques en FortiaAnalizer, y Panorama  (Palo
# Alto). E scalamiento de casos, seguimiento de casos y validación con
# clientes del funcionamiento.  Seguimientos de casos de LAN
# gestionada,  Seguridad Administrada Virtual,  SD-WAN  Gestionada ,
# PBX Gestionada, Exinda, WiFi Gestionado con proveedo res. Servicio
# en c iberseguridad 24/7 en atención a clientes.
# Abril 2019  - Junio  2020  Ingeniero  Residente  NOC  Moviles -
# FRACTALIA
# (Cliente sede Telefónica del Perú ) Analista de Incidencias y solución
# de problemas a clientes en sus redes móviles, area NOC móviles,
# manejo  de sistema de tiquet Remedy para atención de incidencias,
# solución de  problemas r oaming, monitoreo, primera línea de casos
# M2M líneas  smart, usos de los aplicativos para la solución de averias
# móviles  (traffic, GGSN, Qulickview, HLR, PCRF, STC, Empirix,
# AMDOCS, Netac  Nokia,  U2000),  Backoffice,  FrontOffice.
#
#
# Oct 2018 - Marz  2019  Ingeniero  Soporte  Tercer  Nivel - CESCORP
# (Cliente Telefónica del Perú ) Analista de Incidencias y solución de
# problemas de redes móviles, área GICS, manejo de sistema de
# tiquet  Remedy para atención de incidencias, solución de problemas
# roaming,  monitoreo, p rimera línea de casos M2M líneas smart, usos
# de los  aplicativos para la solución de averias móviles (traffic, GGSN,
# Qulickview,  HLR, PCRF, STC,  Empirix,  AMDOCS), Backoffice.
#
#
# Jun 2017  -Agosto  2018    Practicante  TI en TechMahindra
# Coordinación con analistas de los proyectos 3G 4G Microondas,
# Documentación de servicios SGA, Documentación de enlaces
# MW, subir documentación al portal Claro, Solicitud de TSS
# contratistas, verificación, Interacción con analistas para culminar
# a la fecha  los proyectos  programados.
#
# Estudios
# Marz  2011  – Dic 2016  Bachiller  en Ingeniería  Electrónica
# -  Universidad  Nacional  Mayor  de San Marcos  (UNMSM)
# Jul 2023 – Oct 2023   Academia de C iberseguridad – Gestión de un
# CyberSOC : SIEM, XDR, SOAR, Threat intelligence, Threat Hunting, Dark
# Web, Deception Technology y Brand Protection.
#
# Jul 2023 – Al presente  Academia de C iberseguridad  - ISO/IEC 27001
# implementacion de un SOC.
#
# Feb 2023 – May 2023  Certificado en  NSE1, NSE2, NSE3  y en preparación
# para el NSE4 Fortinet
#
# Jul 202 2 – Ago 202 2 Taller de ITIL V4 – Certificación  – SISTEMAS UNI
# Nov 2106  – Set 2018  Diplomado  Redes  Cisco  CCNA  1, CCNA 2,
# CCNA 3, CCNA 4 - INICTEL UNI
# Ene 2017 – Abr 2017       EXCEL  Avanzado  (Escuela  Internacional
# de Gerencia  EIGER  )
# Ene 2016  –  Al Presente  INGLES  Intermedio  6 ICPNA
# May 2023 – Jul 2023  Udemy Academy – Palo Alto Network preparación
# para el PCNA y Fortinet
# Objetivo  Laboral
#
# “Mis cualidades el  gusto por el esfuerzo, rápido  aprendizaje, trabajo  en equipo y entusiasmo
# por mejorar día a día para el éxito  empresarial  apoyando con mis conocimientos y
# virtudes” David Staling Valverde Valdiglesias11 de octubre de 2023
# Powered by TCPDF (www.tcpdf.org)david valverde
# NSE 1 Network Security Associate
# AqAEpPvxiiJanuary 19, 2023
# January 19, 2025
# Powered by TCPDF (www.tcpdf.org)david valverde
# NSE 2 Network Security Associate
# hoi43LkiywJanuary 19, 2023
# January 19, 2025
# Powered by TCPDF (www.tcpdf.org)david valverde
# NSE 3 Network Security Associate
# IJvXYBYoo6January 24, 2023
# January 24, 2025
# Powered by TCPDF (www.tcpdf.org)
#
#
# Lima, 30 de Junio del 2020
#
#
# CERTIFICADO DE TRABAJO
#
#
# POR MEDIO DE LA PRESENTE CERTIFICAMOS:
#
# Que, el(la) Sr.( Srta.)  VALVERDE VALDIGLESIAS DAVID STALING  identificado(a) con DNI Nº
# 47485810  ha laborado en nuestra empresa desde el 01 de Abril del 2019  al 30 de Junio del 2020
# desempeñando el cargo de  Operador N1/Ing Residente N1 .
#
# Se expide el presente certificado a solicitud de la parte interesada para los fines que estime
# convenientes.
#
# Atentamente,
#
#
#
#
#
# FRACTALIA  PERU S.A.
#
#
#  Contenido del CV: SUAREZ AGUILAR CRISTOPHER DAVID Curso de Ingles
# Curso de ingles en la institución "Centro
# Ecuatoriano Norteamericano" (CEN).Soy una persona proactiva, excelente compañero de equipo, organizado y responsable. Disfruto
# mucho aprender cosas nuevas, por lo que mi objetivo es un puesto desafiante y dinámico donde
# poder compartir mi experiencia y a su vez sumar nuevos conocimientos.
# Unidad Educativa "Jambeli"
#  Bachiller en AcuaculturaEDUCACIÓN EXPERIENCIA LABORAL
# Universidad de Guayaquil
# Cursando 9no semestre de la carrera
# Ingeniería en Técnologia de la Información y
# Comunicación.
# CURSOS / HABILIDADES
# Curso de informática
# Conocimiento avanzado. Empresa Global Hitss Ecuador
# • Pasante del área de "Desktop y Perifericos" unidad
# 14.
# • Pasante del área de "Procesos - Segmento Masivo"
# unidad 04.suarezdavid251@gmail.com Cel: 0967830149
# SOBRE MI
# IDIOMAS
# Ingles - básico / intermedioDatos personales
# Cristopher David Suarez Aguilar
# cristopher.suarezag@ug.edu.ec• Nombres completos:
# • Correo institucional:
# • C.I.: 0706048964
# • Fecha de nacimiento: 4 de octubre de 1999
# • Estado Civil: Soltero
# • Edad: 23 años Samanes 1 manzana 101 villa 43
# Prácticas comunitarias
# • Realización de prácticas comunitarias en la
# explanada de Mucho Lote, Guayaquil. - Centro de
# Vacunación.
# Cualidades
# Liderazgo, servicio y motivación.
# Atención al cliente.
# Experiencia en máquinas virtuales,
# ordenadores, etc.
#
#  Contenido del CV:  CURRÍCULA DEL PERSONAL
#
#
# USO INTERNO DE GLOBAL HITSS  Fecha de emisión:
# 30 de abril del 2020  Código:
# HI-A-P03-F02 Versión: 08 Página 1 de 3
#
#
# Nombre  Completo : Daniel Aguilar Uribe
# Datos de Contacto:  Número móvil : 5617473187
#
# Correo electrónico : daniel_94@hotmail.com
#
# Resumen
# profesional  Llevo mas de 5 años desempeñando el puesto como desarrollador de
# aplicaciones móviles para la plataforma de Android  dirigidas al sector
# industrial y bancario. En algunas de ellas participando desde la planeación
# del proyecto y en otras uniéndome a equipos ya consolidados.
# Además tengo conocimientos backend por lo que he desarrollado mis
# propias APIs para el consumo de servicios móvile s.
#
# Resumen de
# habilidades
# técnicas  Java ( 5 años ),
# Kotlin  (2 años ),
# Desarrollo web (2  años ),
# JavaScript ( 2 años ),
# PHP (2 años ),
# JQuery  (1 año),
# Python  (1 año),
# MySLQ (2años), SpringBot (1 año), Hibernate (1 año)
#
# Experiencia
# Profesional  IDS Comercial | CDMX  | fecha de inicio  (02-2020 ) – (03-2022)
# Puesto : Android  Developer  SR
# Actividades:
#
# • Desarrollo de banca móvil desde cero, participación en los
# módulos de on boarding, login, dashboard, transferencias, pago
# de servicios.
# • Implementación de medidas de seguridad
# • Consumo de API Rest
# • Solución de Errores del aplicativo
# • Manejo de analíticas de la  aplicación
#
# Herramientas/ Tecnologías:  Java /Kotlin , Firebase , Retrofit ,  Room, Shared
# Preferences, Glide, Dagger, Live Data, Data Binding
#
#
#   CURRÍCULA DEL PERSONAL
#
#
# USO INTERNO DE GLOBAL HITSS  Fecha de emisión:
# 30 de abril del 2020  Código:
# HI-A-P03-F02 Versión: 08 Página 2 de 3
#
#
# Fabric Images International | Naucalpan , Edo. Méx.  | fecha de inicio  (12-
# 2016 ) - fecha de fin  (02-2020 )
# Puesto : Android Developer JR
# Actividades:
# • Diseño y desarrollo de aplicativo móvil para gestión de recursos
# (humanos, técnicos y materiales) en tiempo real mediante un
# scanner de QR, desarrollo de métricas dentro de la aplicación
# para costeo de proyectos, inventario de almacén, visualización de
# renders y planos.
# • Desarrollo de servicios backend
# Herramientas/ Tecnologías:  Java , Firebase, API de Google Maps, SQLite,
# SQL, PHP, Notificaciones Push, Zxing.
#
# Habilidades
# Técnicas  Sistemas Operativos
# • Windows, MacOS, CentOS, Ubuntu, Fedora
#
# Lenguajes de Programación
# • Java, Kotlin, PHP, JS, Python, C
#
# Bases de datos
# • MySQL, Oracle
#
# Metodologías
# • SCRUM
#
#
#
#
# Diplomados
#  Nombre del Diplomado  | Escuela  | Período
#
#
#
# Cursos y
# Certificaciones
#  Nombre del Curso y Certificado  | Escuela  | Período
#
# Universidad Java  | Udemy  | 2019
# Scrum Master | Certi Prof  | 2021  ID: FLTJSDJBJT -DQLHGLJD -
# WHQHWDFNHK
#
#
#   CURRÍCULA DEL PERSONAL
#
#
# USO INTERNO DE GLOBAL HITSS  Fecha de emisión:
# 30 de abril del 2020  Código:
# HI-A-P03-F02 Versión: 08 Página 3 de 3
#
#
# Educación  Ultimo grado de estudios | Escuela  | Período
#
# Licenciatura en Matemáticas Aplicadas y Computación  | FES Acatlán  |
# 2012 - 2017
#
# Inglés  • Leído  60%
# • Escrito  50%
# • Hablado  50%
#
#
#  Contenido del CV:  CURRÍCULA DEL PERSONAL
#
#
# USO INTERNO DE GLOBAL HITSS  Fecha de emisión:
# 30 de abril del 2020  Código:
# HI-A-P03-F02 Versión: 08 Página 1 de 2
#
#
# Nombre  Completo : David Ulisses Arenas Aguilar
# Datos de Contacto:  Número móvil : 248-173-13-22
#
# Correo electrónico : arenasaguilarulisses@gmail.com
#
# Resumen
# profesional  Desarrollar algoritmos en diferentes lenguajes de
# programación para módulos en el funcionamiento de software
# autónomos, control y aplicación. Contr ibuyendo con
# propuestas creativas, siendo proactivo.
#
# Resumen de
# habilidades
# técnicas  Programación en Java (6  años)
# J2EE  (6 años)
# Desarrollo web (6  años)
# JavaScript (6  años)
# Base de Datos (6  años)
# Servidores (6  años)
# Movil (4  años)
#
# Experiencia
# Profesional  Grupos Salinas, Afore Azteca | Ciudad de Mexico, Cdmx | fecha de inicio
# (Marzo 2018 y Actual) - Actual
# Puesto: Desarollador en Front -end
# Banca Digital (Banco Azteca)  desarrollo, corrección y mantenimiento de
# Api´s
# Área Afore Azteca , implementación de servicios SOAP/REST, análisis
# modificación y corrección de Store Procedure O racle.
# Actividades: Desarr ollad or en sistemas Front -end.
# Entorno: SQLDeveloper, Eclipse Mars 2, NetBeans, JDK 1.7, JDK 1.8,
# Windows 10, WebLogic 12c Herramientas: HTML, XHTML, CSS, Javascript,
# Spring, HTML, JSF.
#
# GRUPO FINANCIERO INBURSA | Ciudad de Mexico, Cdmx | fecha de
# inicio (Marzo y 2016) - fecha de fin (Mayo y 2018)
# Puesto: Desarollador Actividades: Desarrollador en lenguaje java con
# arquitectura Struts 1 analista de requerimien tos para el usuario del
# sistema.
# Entorno: NetBeans, JDK 1.8, Linux, Eclipse, SpringTools,  JDK 1.6, JDK 1.7,
# WebLogic, Oracle 11g, GlassFish 3.3, GlassFish 4.1, WebLogic, Oracle 11g,
# GlassFish 3.3.
#   CURRÍCULA DEL PERSONAL
#
#
# USO INTERNO DE GLOBAL HITSS  Fecha de emisión:
# 30 de abril del 2020  Código:
# HI-A-P03-F02 Versión: 08 Página 2 de 2
#
#
# Herramientas: Spring, HTML, Javascript, CSS. Struts, JSF, Primefaces,,
# XML, XHTML,HTML,JSP, CSS, JavaScript, JQuery
#
# Habilidades
# Técnicas  Manejo de Software :
#  -Lenguaje: C, C++, Java, SQL, OpenGL, HTML, XHTML, XML, JavaScript,
# CSS, HTML 5, -IDE’s: Eclipse, NetBeans, MyEclipse.
# -Frameworks y otros: JQuery, Struts, IBatis, Servlet, EJB, JSP, Hibernate,
# Jasper Report.
# -Base de Da tos: Oracle, SQL Server, MySQL.
# -Servidores: GlassFish, JBoss, Apache Tomcat, WebLogic.
# -Paquetería: Word, Excel, Power Point, Access, Publisher.
#
# Diplomados
#  Nombr e del Diplomado  | Escuela  | Período
#
# Cursos y
# Certificaciones
#  Nombre del Curso y Certificado  | Escuela  | Período
# Reconoci miento por participación obteniendo 3er lugar en el Torneo
# Mexicano de Robótica (Edo. México, 2012), 2do lugar en el Torneo
# Mexicano de Robótica (Puebla Pue, 2013), 3er lugar en el Torneo
# Mexicano de Robótica (CD. Carmen, 2014) y Participación en el Torneo
# Mexicano de Robótica (FES Acatlán, 2015). Certificado de Participación en
# la RoboCup 2014 celebrada en Joao Pessoa Brasil Reconocimiento de
# Participación en la Escuela de Invierno de Robótica (EIR 2013 y 2015).
#
# Educación  Ultimo grado de estudios | Escuela  | Período
# Instituto Tecnológico Superior de San Mart ín Texmelucan (ITSSMT)|
#
# Inglés   Leído 30%
#  Escrito 20%
#  Hablado 10%

# %%
for i in range(len(folder)):
    print(folder[i], filename[i])
# Out:
# /Documentos compartidos/General/ECUADOR AGUILAR PAZMIÑO DAVID ALEXIS.pdf
# /Documentos compartidos/General/ECUADOR PAZMIÑO SALAS JOSE ANTONIO.pdf
# /Documentos compartidos/General/PERÚ DAVID STALING VALVERDE VALDIGLESIAS.pdf
# /Documentos compartidos/General/ECUADOR SUAREZ AGUILAR CRISTOPHER DAVID.pdf
# /Documentos compartidos/General/PruebaPDF DANIEL AGUILAR URIBE.pdf
# /Documentos compartidos/General/PruebaPDF DAVID ULISSES ARENAS AGUILAR.pdf

# %% [markdown]
# ### Open AI tests

# %%
_, respuesta = azure_openai(query, prompt_results=cognitive, isIntro=False)


json_data = json.loads(respuesta)
contenido = json_data["content"]

print(contenido)
# Out:
# El resumen del currículum de **David Aguilar Pazmiño** es el siguiente:
#
# - Bachiller Contable del Colegio Fiscal Técnico Provincia de Bolívar, Guayaquil.
# - Experiencia laboral en atención al cliente y soporte técnico en Telenews y Publinext S.A.
# - Ingeniero en Networking y Telecomunicaciones de la Universidad de Guayaquil.
# - Cursos y certificaciones en instalador de fibra óptica, fundamentos de Networking para redes IP, conectividad IP y protocolo de ruteo, técnico en seguridad informática, técnico en sistemas informáticos, entre otros.
# - Habilidades en liderazgo en equipo, proactividad, resiliencia, paquete Microsoft Office, aplicaciones de seguridad, conocimiento en routers de marcas CISCO, TP-Link y HUAWEI.
# - Nivel intermedio en idioma inglés.
#
# Si necesitas más detalles sobre algún aspecto en particular, no dudes en preguntar.

# %%
folder, filename = selecciona_rutas(cognitive, contenido, folder, filename)
print(folder, filename)
# Out:
# ['DAVID AGUILAR PAZMINO']
# ['/Documentos compartidos/General/ECUADOR', '/Documentos compartidos/General/ECUADOR'] ['AGUILAR PAZMIÑO DAVID ALEXIS.pdf', 'SUAREZ AGUILAR CRISTOPHER DAVID.pdf']
